# %% [markdown]
# # extract features from each publisher and advertiser webpage

# %%
# database packages
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2

# math
import pandas as pd
import numpy as np
# %matplotlib inline

# nlp
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.snowball import SnowballStemmer
import re
import nltk

# %%
# input from the webpage db
dbname = 'urx'
username = 'noahburbank'
engine = create_engine('postgres://%s@localhost/%s'%(username,dbname))

# %%
# connect:
con = None
con = psycopg2.connect(database = dbname, user = username)

# query:
sql_query = """
SELECT * FROM webpage_data_table_exp2;
"""
webpage_data = pd.read_sql_query(sql_query,con)
webpage_data.columns
# Out:
# Index([u'index', u'starturl', u'start_domain', u'start_titles',
#        u'start_description', u'start_extracted_content',
#        u'start_stemmed_word_list', u'_unit_it', u'endurl', u'end_domain',
#        u'end_titles', u'end_decription', u'end_extracted_content',
#        u'end_stemmed_word_list'],
#       dtype='object')

# %% [markdown]
# # tfidf

# %%
# tokenizer
stemmer = SnowballStemmer("english")
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
#### tf-idf  

def get_tfidf_cosine_measure(start_texts, end_texts):
    # combine all of the texts
    all_texts = list(start_texts) + list(end_texts)
    
    # initialize and train 
    tfidf = TfidfVectorizer(tokenizer=tokenize_and_stem, stop_words='english')
    tfs = tfidf.fit_transform(all_texts)

    # make the cosine similarity matrix 
    cosine_mat = tfs * tfs.T
    
    # grab the cosine similarity measure for each start/end url pair and output as a list
    cosine_list = []
    indexer = range(0, len(start_texts))
    for index in indexer:
        cosine_val = cosine_mat[index, index + len(start_texts)]
        cosine_list.append(cosine_val)
    return cosine_list, tfidf

# %%
# get cosine similarity for each piece of the document 
title_cosine, title_tfidf = get_tfidf_cosine_measure(webpage_data['start_titles'], webpage_data['end_titles'])
body_cosine, body_tfidf = get_tfidf_cosine_measure(webpage_data['start_extracted_content'], webpage_data['end_extracted_content'])
meta_cosine, meta_tfidf = get_tfidf_cosine_measure(webpage_data['start_description'], webpage_data['end_decription'])

# %% [markdown]
# # n-grams

# %%
# trying the one, two and three grams
import ngram
one_grams = []
two_grams = []
three_grams = []

for line in webpage_data.iterrows():
    string1 = line[1]['start_titles']
    string2 = line[1]['end_titles']
    one_gram = ngram.NGram.compare(string1, string2, N=1)
    two_gram = ngram.NGram.compare(string1, string2, N=2)
    three_gram = ngram.NGram.compare(string1, string2, N=3)
    one_grams.append(one_gram)
    two_grams.append(two_gram)
    three_grams.append(three_gram)

# %%
description_one_grams = []
description_two_grams = []
description_three_grams = []

for line in webpage_data.iterrows():
    string1 = line[1]['start_description']
    string2 = line[1]['end_decription']
    one_gram = ngram.NGram.compare(string1, string2, N=1)
    two_gram = ngram.NGram.compare(string1, string2, N=2)
    three_gram =ngram.NGram.compare(string1, string2, N=3)
    description_one_grams.append(one_gram)
    description_two_grams.append(two_gram)
    description_three_grams.append(three_gram)

# %% [markdown]
# # longest common substring

# %%
 def longest_common_substring(s1, s2):
    m = [[0] * (1 + len(s2)) for i in xrange(1 + len(s1))]
    longest, x_longest = 0, 0
    for x in xrange(1, 1 + len(s1)):
        for y in xrange(1, 1 + len(s2)):
            if s1[x - 1] == s2[y - 1]:
                m[x][y] = m[x - 1][y - 1] + 1
                if m[x][y] > longest:
                    longest = m[x][y]
                    x_longest = x
            else:
                m[x][y] = 0
    return s1[x_longest - longest: x_longest]

# %%
from nltk.corpus import stopwords

stopwords = stopwords.words('english')

lcfs = []
limiter = 0
desc_vectors = []
body_vectors = []
title_vectors = []
title_to_body = []

def lcf_strings(string1, string2):
    lcf = longest_common_substring(string1, string2)
    lcfs.append(lcf)
    
    x = tokenize_only(lcf)
    x = set(x).difference(stopwords)
    if x != set():
        if len(max(x)) < 3:
            x = set()
    return x

# %%
i = len(webpage_data)
for line in webpage_data.iterrows():
    
    desc_vectors.append(lcf_strings(line[1]['start_description'], line[1]['end_decription']))
    body_vectors.append(lcf_strings(line[1]['start_extracted_content'], line[1]['end_extracted_content']))
    title_vectors.append(lcf_strings(line[1]['start_titles'], line[1]['end_titles']))
    title_to_body.append(lcf_strings(line[1]['start_titles'], line[1]['end_extracted_content']))
    if (i % 25) == 0:
        print i
    i -= 1
# Out:
# 950
# 925
# 900
# 875
# 850
# 825
# 800
# 775
# 750
# 725
# 700
# 675
# 650
# 625
# 600
# 575
# 550
# 525
# 500
# 475
# 450
# 425
# 400
# 375
# 350
# 325
# 300
# 275
# 250
# 225
# 200
# 175
# 150
# 125
# 100
# 75
# 50
# 25

# %%
def process_lcf_list(lcf_list, cutoff):

    # convert to strings
    vec = []
    for item in lcf_list:
        vec.append(str(item))
    
    # make dictionary with counts of each unique term (set of sets converted to string)
    unique_sets = list(set(vec))
    zeros = [0] * len(set(vec))
    set_lists = dict(zip(unique_sets, zeros))
    for desc_set in vec:
        set_lists[desc_set] += 1
       
    #print set_lists
    
    # evaluate where to cutoff these values
    print "there are " + str(len(vec)) + ' entries'
    print 'of which ' + str(len(set_lists.values())) +' are unique values'
    print 'of which ' + str(pd.Series(data=set_lists.values()).apply(lambda x: x > cutoff).sum()) + ' are too frequent to matter'
    print 
    print 'too frequent entries:' + " for " + str(cutoff) + " as cutoff"
    
    # find the items 
    acceptable_sets = []
    lcf_score = []
    for line in set_lists:
        if set_lists[line] < cutoff and set_lists[line] > 1:
            acceptable_sets.append(line)
#    print 'these are the acceptable sets'
#    print acceptable_sets
    
    #calculate the score for each one
    for line in lcf_list:
        if str(line) in set(acceptable_sets):
            lcf_score.append(1)
        else:
            lcf_score.append(0)
            
            
# it looks like 10 is a pretty good choice 
    return lcf_score

# %%
desc_lcf_score = process_lcf_list(desc_vectors,6)
# Out:
# there are 950 entries
# of which 251 are unique values
# of which 5 are too frequent to matter
#
# too frequent entries: for 6 as cutoff

# %%
title_lcf_score = process_lcf_list(title_vectors,6)
# Out:
# there are 950 entries
# of which 352 are unique values
# of which 5 are too frequent to matter
#
# too frequent entries: for 6 as cutoff

# %%
body_lcf_score = process_lcf_list(body_vectors, 6)
# Out:
# there are 950 entries
# of which 262 are unique values
# of which 11 are too frequent to matter
#
# too frequent entries: for 6 as cutoff

# %% [markdown]
# # named entitiy recognition

# %%
## named entity recognition 
from nltk.tag.stanford import StanfordNERTagger
st = StanfordNERTagger('/Users/noahburbank/Python/stanford-ner/stanford-ner-2014-06-16/classifiers/english.all.3class.distsim.crf.ser.gz',
                       '/Users/noahburbank/Python/stanford-ner/stanford-ner-2014-06-16/stanford-ner-3.4.jar')

# %%
# make the string back into a list object

# function to get lists back into lists(they're actually sets though, so the order is an issue)
def strings_back_to_lists(string):
    string = string.replace('{', '')
    string = string.replace('}', '')
    string = unicode(string, errors='ignore')

    mylist = string.split(',')
    
    return mylist

# %%
##  this will extracted the person named entities for a each page

def extract_named_entities(word_set, max):
    counter = 0
    named_entities = []
    for word_list in word_set:
        word_list = strings_back_to_lists(word_list)
        tuple_list = st.tag(word_list)


        entities = []
        for element in tuple_list:
            if element[1] == 'PERSON':
                entities.append(element[0])

        named_entities.append(entities)

        counter += 1
        print entities
#        print 
#        print 
        if counter == max:
            break
    return named_entities

# %%
## extract named entities for each part of the 

start_body_ner = extract_named_entities(webpage_data.start_stemmed_word_list, 10000)
end_body_ner = extract_named_entities(webpage_data.end_stemmed_word_list, 10000)
# Out:
# [u'lavern', u'baker']
# [u'lavern', u'baker']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'doc', u'mcstuffin']
# [u'doc', u'mcstuffin']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'nicki', u'minaj', u'nicki', u'minaj', u'scott', u'antidot', u'nicki', u'minaj', u'nicki', u'minaj', u'nicki', u'minaj', u'jimmi', u'kimmel']
# [u'zac', u'efron', u'nikki', u'blonski', u'amanda', u'byne', u'elijah', u'kelley']
# [u'zac', u'efron', u'nikki', u'blonski', u'amanda', u'byne', u'elijah', u'kelley']
# []
# []
# [u'bob', u'power', u'nicki', u'minaj', u'nicki', u'minaj']
# []
# []
# []
# []
# [u'ben', u'affleck', u'kevin', u'tsujihara', u'zack', u'snyder', u'kevin', u'smith']
# [u'saul', u'hudson', u'michael', u'mckagan', u'jeffrey', u'isbel', u'steven', u'adler', u'montel', u'jordan', u'ricki', u'walter']
# [u'saul', u'hudson', u'michael', u'mckagan', u'jeffrey', u'isbel', u'steven', u'adler', u'montel', u'jordan', u'ricki', u'walter']
# []
# []
# [u'paul', u'johnson', u'jame', u'blake', u'jame', u'holden', u'jame', u'holden', u'paul', u'johnson', u'jame', u'blake']
# []
# []
# []
# []
# [u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# []
# []
# [u'jame', u'holden', u'paul', u'johnson', u'jame', u'blake', u'jame', u'holden', u'jame', u'holden', u'paul', u'johnson', u'jame', u'blake']
# [u'jame', u'holden', u'paul', u'johnson', u'jame', u'blake', u'jame', u'holden', u'jame', u'holden', u'paul', u'johnson', u'jame', u'blake']
# [u'anna', u'von', u'hausswolff', u'anna', u'von', u'hausswolff', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'anna', u'von', u'hausswolff', u'anna', u'von', u'hausswolff', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'kendrick', u'lamar', u'snoop', u'eminem', u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'kendrick', u'lamar', u'snoop', u'eminem', u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'paul', u'johnson', u'jame', u'blake', u'jame', u'holden', u'jame', u'holden', u'paul', u'johnson', u'jame', u'blake']
# []
# [u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'arthur', u'russel', u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'arthur', u'russel', u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# []
# [u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'daniel', u'lopatin', u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'daniel', u'lopatin', u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u'john', u'jarrel', u'rza', u'howard', u'drossin', u'paul', u'johnson', u'jame', u'blake', u'paul', u'johnson', u'jame', u'blake']
# [u
# [u'chris', u'brown', u'chris', u'brown', u'chris', u'brown', u'rob', u'kardashian', u'donald', u'trump']
# [u'paul', u'anka', u'paul', u'anka', u'paul', u'anka', u'michael', u'jackson', u'paul', u'anka', u'paul', u'anka']
# [u'rick', u'ross', u'rob', u'kardashian', u'donald', u'trump']
# [u'rob', u'kardashian', u'donald', u'trump']
# [u'rob', u'kardashian', u'donald', u'trump']
# [u'rob', u'kardashian', u'donald', u'trump']
# [u'rob', u'kardashian', u'donald', u'trump']
# []
# []
# [u'ansel', u'elgort']
# [u'ansel', u'elgort']
# []
# []
# []
# [u'eric', u'prydz', u'claud', u'vonstrok', u'pete', u'tong']
# [u'joel', u'zimmerman']
# [u'joel', u'zimmerman']
# []
# []
# [u'luca', u'van', u'scheppingen']
# [u'luca', u'van', u'scheppingen']
# [u'martijn', u'garritsen', u'van', u'kooten', u'van', u'kooten', u'david', u'guetta']
# [u'martijn', u'garritsen', u'van', u'kooten', u'van', u'kooten', u'david', u'guetta']
# [u'kaylyn', u'sommer']
# [u'kaylyn', u'sommer']
# [u'joel', u'zimmerman']
# [u'joel', u'zimmerman']
# [u'eric', u'prydz', u'claud', u'vonstrok', u'pete', u'tong']
# []
# []
# []
# []
# [u'justin', u'bieber', u'kati', u'couric']
# [u'justin', u'bieber', u'kati', u'couric']
# [u'doc', u'martin', u'eddi', u'richard', u'stephen', u'kruse']
# [u'doc', u'martin', u'eddi', u'richard', u'stephen', u'kruse']
# []
# []
# []
# []
# []
# []
# []
# [u'robbi', u'rivera', u'robbi', u'rivera']
# [u'robbi', u'rivera', u'robbi', u'rivera']
# []
# []
# []
# []
# [u'ella', u'fitzgerald']
# [u'ella', u'fitzgerald']
# []
# []
# []
# [u'kenni', u'gambl']
# [u'kenni', u'gambl']
# []
# []
# [u'john', u'fogerti']
# [u'john', u'fogerti']
# []
# [u'mickey', u'gregori']
# [u'mickey', u'gregori']
# []
# []
# [u'delbert', u'mcclinton', u'delbert', u'mcclinton']
# [u'delbert', u'mcclinton', u'delbert', u'mcclinton']
# []
# []
# [u'lynn', u'anderson', u'lynn', u'anderson', u'nolyr', u'lynn', u'anderson', u'lynn', u'anderson']
# []
# [u'lynn', u'anderson', u'lynn', u'anderson', u'nolyr', u'lynn', u'anderson', u'lynn', u'anderson']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'ronni', u'atkin', u'ronni', u'atkin']
# []
# [u'eddi', u'van', u'halen', u'eddi', u'van', u'halen']
# [u'eddi', u'van', u'halen', u'eddi', u'van', u'halen']
# []
# []
# []
# []
# []
# []
# []
# [u'ronni', u'atkin', u'ronni', u'atkin']
# []
# []
# []
# []
# []
# [u'ronni', u'atkin', u'robert', u'mason', u'michael', u'kisk', u'tobia', u'ronni', u'atkin', u'michael']
# [u'ronni', u'atkin', u'robert', u'mason', u'michael', u'kisk', u'tobia', u'ronni', u'atkin', u'michael']
# []
# []
# [u'brian', u'kelley', u'chris', u'tompkin', u'rodney', u'clawson', u'tyler', u'hubbard']
# [u'brian', u'kelley', u'chris', u'tompkin', u'rodney', u'clawson', u'tyler', u'hubbard']
# []
# []
# []
# [u'adam', u'levin', u'lukasz', u'gottwald']
# [u'adam', u'levin', u'lukasz', u'gottwald']
# []
# []
# [u'elena', u'jane', u'pourkarim', u'laleh', u'elli', u'gould', u'dedic']
# []
# []
# [u'paul', u'epworth']
# [u'paul', u'epworth']
# []
# [u'justin', u'bieber']
# [u'justin', u'bieber']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u
# [u'michael']
# [u'daniel', u'craig', u'christoph', u'waltz', u'daniel', u'craig']
# [u'daniel', u'craig', u'christoph', u'waltz', u'daniel', u'craig']
# [u'j.j.', u'abram', u'john', u'boyega']
# [u'j.j.', u'abram', u'john', u'boyega']
# []
# []
# [u'chris', u'hemsworth', u'chris', u'evan', u'robert', u'downey']
# [u'chris', u'hemsworth', u'chris', u'evan', u'robert', u'downey']
# []
# []
# [u'chris', u'jericho', u'sorri', u'dwayn', u'johnson']
# [u'chris', u'jericho', u'sorri', u'dwayn', u'johnson']
# [u'eddi', u'redmayn', u'alan', u'rickman', u'legendari', u'harri', u'potter']
# [u'eddi', u'redmayn', u'alan', u'rickman', u'legendari', u'harri', u'potter']
# []
# []
# [u'jim', u'henson']
# [u'jim', u'henson']
# [u'joss', u'whedon', u'joss', u'whedon']
# [u'joss', u'whedon', u'joss', u'whedon']
# []
# [u'dee', u'dee', u'bridgewat']
# []
# []
# [u'robin', u'hood', u'elison', u'jackson']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'janet', u'jackson']
# [u'andrew', u'mcmahon']
# []
# []
# []
# [u'brandon', u'wetherbe']
# []
# []
# []
# [u'toni', u'bennett', u'toni', u'bennett', u'toni', u'bennett']
# [u'nicki', u'minaj', u'darl', u'nicki']
# []
# []
# []
# []
# [u'ali', u'shahe', u'moham', u'ron', u'carter']
# []
# []
# []
# []
# [u'noel', u'neill', u'lex', u'luthor']
# []
# []
# []
# []
# [u'jame', u'holden', u'julia', u'biel']
# []
# []
# []
# [u'daniell', u'bradberi', u'brett', u'eldredg']
# []
# []
# []
# []
# []
# []
# [u'anna', u'von', u'hausswolff', u'anna', u'von', u'hausswolff', u'anna', u'von', u'hausswolff', u'carl', u'michael', u'von', u'hausswolff', u'anna', u'von', u'hausswolff']
# []
# [u'kendrick', u'lamar', u'marsha', u'ambrosius', u'kendrick', u'lamar', u'justus', u'anderson', u'jill', u'scott', u'jon', u'connor', u'anderson', u'marsha', u'ambrosius', u'kendrick', u'lamar', u'jon', u'connor']
# []
# []
# [u'ani', u'contemporari', u'chris', u'brown']
# [u'jerri', u'butler']
# []
# []
# []
# []
# []
# [u'daniel', u'lopatin', u'daniel', u'lopatin']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'noah', u'lennox', u'josh', u'dibb', u'brian', u'weitz', u'brendan', u'fowler', u'portner', u'weitz']
# []
# []
# []
# []
# []
# []
# [u'daniel', u'lanoi', u'roger', u'eno']
# []
# []
# []
# []
# []
# []
# [u'joe', u'nichol']
# [u'joe', u'nichol']
# []
# []
# [u'brantley', u'gilbert', u'michael', u'ray', u'brantley', u'gilbert']
# [u'brantley', u'gilbert', u'michael', u'ray', u'brantley', u'gilbert']
# []
# []
# []
# [u'rachel', u'platten']
# []
# []
# []
# []
# [u'garrett', u'dutton']
# [u'garrett', u'dutton']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u
# [u'deborah', u'cox', u'dejuan', u'turentin', u'erica', u'campbel', u'chaka', u'khan', u'gerald', u'levert', u'yolanda', u'adam', u'carl', u'thoma']
# []
# [u'rachel', u'platten']
# []
# []
# []
# []
# []
# [u'bruce', u'foxton', u'buckley']
# [u'rachel', u'platten']
# [u'jorg', u'cordero']
# [u'rachel', u'platten']
# []
# [u'rachel', u'platten']
# [u'billi', u'flynn']
# [u'rachel', u'platten']
# [u'scott', u'seth', u'avett', u'joe', u'kwon', u'bob', u'crawford', u'gari', u'clark']
# [u'rachel', u'platten']
# [u'jane', u'lee', u'hooker']
# [u'berl', u'collin', u'olga', u'queen', u'dick', u'grayson', u'cassandra']
# [u'justin', u'bieber', u'justin', u'bieber', u'justin', u'bieber', u'jason', u'aldean', u'thoma', u'rhett']
# [u'rachel', u'platten']
# []
# [u'rachel', u'platten']
# []
# [u'rachel', u'platten']
# []
# [u'nick', u'heyward']
# [u'rachel', u'platten']
# [u'santa', u'monica', u'santa', u'monica']
# [u'rachel', u'platten']
# [u'brandon', u'wetherbe']
# [u'rachel', u'platten']
# [u'needtobreath', u'santa', u'barbara', u'granada', u'britt', u'nicol', u'colton', u'dixon', u'phil', u'wickham', u'phil', u'wickham']
# [u'rachel', u'platten']
# []
# [u'rachel', u'platten']
# []
# []
# [u'rachel', u'platten']
# []
# [u'rachel', u'platten']
# []
# [u'rachel', u'platten']
# []
# []
# [u'ron', u'pope']
# ...
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'denni', u'rayel', u'cristoph', u'hardi', u'eric', u'mendosa']
# []
# [u'rick', u'lee', u'radiomix']
# []
# []
# []
# []
# [u'luke', u'van', u'scheppingen', u'collin', u'mcloughlin']
# [u'luke', u'van', u'scheppingen', u'collin', u'mcloughlin']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'morrissey', u'bruce', u'springsteen']
# [u'morrissey', u'bruce', u'springsteen']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'jame', u'walsh', u'jame', u'walsh']
# [u'nari', u'milani', u'nari', u'milani']
# []
# []
# [u'pete', u'tong']
# []
# []
# [u'roger', u'cicero']
# []
# [u'emmanuel', u'santa', u'barbara', u'campbel']
# [u'dave', u'kelli']
# [u'billi', u'walton', u'billi', u'walton']
# []
# []
# []
# [u'john', u'fogerti']
# []
# []
# [u'john', u'f.', u'kennedi']
# []
# [u'willi', u'taylor']
# [u'delbert', u'mcclinton']
# [u'delbert', u'mcclinton']
# []
# [u'richard', u'nader', u'mitch', u'ryder']
# []
# []
# [u'paul', u'anka', u'lynn', u'lynn', u'memori']
# []
# []
# []
# []
# []
# []
# [u'ron', u'sayer']
# []
# []
# []
# [u'kevin', u'richard', u'blackwood']
# [u'jimmi', u'buffett', u'huey', u'lewi']
# [u'jimmi', u'buffett', u'huey', u'lewi']
# []
# []
# []
# []
# [u'max', u'lilja', u'antero', u'manninen']
# [u'alain', u'johann', u'dave', u'grohl', u'joshua', u'homm', u'paul', u'mccartney', u'dave', u'grohl', u'krist', u'novosel', u'rick', u'springfield', u'dave', u'grohl', u'taylor', u'hawkin', u'nate', u'mendel']
# [u'alain', u'johann', u'dave', u'grohl', u'joshua', u'homm', u'paul', u'mccartney', u'dave', u'grohl', u'krist', u'novosel', u'rick', u'springfield', u'dave', u'grohl', u'taylor', u'hawkin', u'nate', u'mendel']
# []
# []
# []
# []
# []
# [u'corey', u'taylor', u'joel', u'ekman', u'jim']
# []
# []
# [u'linda', u'blair']
# []
# []
# []
# []
# [u'mike', u'wead']
# []
# [u'ronni', u'atkin', u'pete', u'collin', u'john', u'darrow', u'ricki', u'hansson', u'allan', u'discov']
# []
# []
# [u'roth', u'eddi', u'van', u'halen', u'david', u'lee', u'roth']
# []
# []
# []
# []
# []
# []
# [u'chris', u'goss', u'dave', u'grohl', u'alain', u'johann']
# [u'ronni', u'atkin', u'pete', u'collin', u'john', u'darrow', u'ricki', u'hansson', u'allan', u'discov']
# []
# []
# []
# []
# []
# [u'leighton', u'meester']
# []
# [u'sergio', u'vega']
# [u'sergio', u'vega', u'billi', u'corgan']
# [u'jason', u'aldean', u'thoma', u'rhett', u'jason', u'aldin', u'jason', u'aldean', u'rhett', u'atkin']
# [u'jason', u'aldean', u'thoma', u'rhett', u'jason', u'aldin', u'jason', u'aldean', u'rhett', u'atkin']
# []
# []
# []
# []
# []
# []
# [u'justin', u'bieber']
# []
# []
# []
# []
# []
# []
# [u'justin', u'bieber', u'justin', u'bieber', u'justin', u'bieber', u'jason', u'aldean', u'thoma', u'rhett']
# [u'justin', u'bieber', u'justin', u'bieber', u'justin', u'bieber', u'jason', u'aldean', u'thoma', u'rhett']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'aiko', u'aiko', u'vienna']
# [u'jason', u'derlo']
# [u'jason', u'derlo']
# []
# []
# []
# [u'kendrick', u'scott', u'oracl', u'jalisco', u'teatro', u'vivian', u'blumenth']
# []
# []
# []
# []
# []
# []
# [u'jenni', u'black', u'jack', u'randal']
# []
# []
# []
# [u'ramiro', u'lopez']
# []
# []
# []
# []
# []
# []
# [u'jon', u'boden', u'neil', u'mcsweeney']
# [u'jon', u'boden', u'neil', u'mcsweeney']
# [u'kenni', u'roger', u'linda', u'davi']
# [u'kevin', u'richard', u'blackwood']
# [u'kenni', u'roger', u'linda', u'davi']
# [u'van', u'morrison', u'van', u'morrison', u'georg', u'ivan', u'morrison']
# [u'van', u'morrison', u'van', u'morrison', u'georg', u'ivan', u'morrison']
# []
# []
# []
# []
# []
# [u'jenni', u'black', u'jack', u'randal']
# []
# []
# []
# []
# []
# [u'patti', u'smith']
# [u'sam', u'sam', u'kevin', u'ohara', u'kevin', u'leav', u'kelli', u'slater', u'bill', u'apart', u'onli']
# [u'cyndi', u'lauper']
# []
# []
# []
# []
# [u'sam', u'sam', u'kevin', u'ohara', u'kevin', u'leav', u'kelli', u'slater', u'bill', u'apart', u'onli']
# []
# []
# [u'jess', u'leach', u'adam', u'dutkiewicz']
# [u'john', u'goodman']
# [u'nigel', u'barker', u'naomi', u'campbel', u'karolina', u'kurkova', u'elisabeth', u'murdoch', u'paul', u'franklin', u'andrew', u'frank', u'patrick', u'demarcheli', u'wendi', u'william', u'naomi', u'karolina', u'nigel', u'barker']
# [u'alain', u'johann', u'dave', u'grohl', u'joshua', u'homm', u'paul', u'mccartney', u'dave', u'grohl', u'krist', u'novosel', u'rick', u'springfield', u'dave', u'grohl', u'taylor', u'hawkin', u'nate', u'mendel']
# [u'alain', u'johann', u'dave', u'grohl', u'joshua', u'homm', u'paul', u'mccartney', u'dave', u'grohl', u'krist', u'novosel', u'rick', u'springfield', u'dave', u'grohl', u'taylor', u'hawkin', u'nate', u'mendel']
# []
# []
# [u'david', u'draiman']
# []
# []
# []
# []
# []
# []
# []
# []
# [u
# []
# [u'jason', u'wrobel']
# [u'denis']
# [u'derek', u'decid', u'jake', u'continu']
# [u'neil', u'avedon', u'lester', u'hoffman', u'neil', u'avedon', u'richard', u'cross', u'hoffman', u'lester', u'testifi', u'neil', u'avedon', u'justin', u'richard', u'cross']
# [u'robin', u'griffin', u'holli', u'hunter']
# [u'robin', u'griffin', u'holli', u'hunter']
# []
# [u'joss', u'whedon', u'ami', u'biancolli']

# %%
start_title_ner = extract_named_entities(webpage_data.start_titles, 10000)
end_title_ner = extract_named_entities(webpage_data.end_titles, 10000)
# Out:
# [u'LAVERN']
# [u'LAVERN']
# []
# []
# []
# []
# []
# []
# []
# [u'Missy']
# []
# [u'DOC']
# [u'DOC']
# []
# []
# [u'HEATHER']
# [u'HEATHER']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Batman']
# []
# []
# []
# []
# []
# []
# []
# [u'BETTE']
# [u'BETTE']
# []
# []
# []
# [u'James']
# [u'James']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Steve']
# [u'Steve']
# []
# []
# []
# []
# [u'Jean-Michel']
# [u'Jean-Michel']
# []
# []
# []
# []
# []
# [u'Reba']
# [u'Reba']
# []
# []
# [u'Brantley']
# [u'Brantley']
# []
# []
# [u'Missy']
# []
# []
# []
# [u'Brian']
# [u'Brian']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Joe']
# [u'Joe']
# [u'Ted']
# [u'Ted']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'August']
# []
# [u'August']
# []
# []
# []
# []
# []
# []
# []
# [u'Ed']
# [u'Ed']
# []
# []
# []
# []
# []
# [u'BRUCE']
# [u'BRUCE']
# []
# []
# []
# []
# []
# [u'GERARDO']
# [u'GERARDO']
# []
# []
# [u'JUSTIN']
# [u'JUSTIN']
# []
# []
# []
# []
# []
# []
# [u'BRIAN']
# [u'BRIAN']
# []
# []
# [u'MARVIN']
# [u'MARVIN']
# []
# []
# []
# []
# [u'KAREN']
# [u'KAREN']
# []
# [u'John']
# []
# []
# []
# []
# []
# [u'Jeff']
# [u'Jeff']
# [u'Seu']
# [u'Seu']
# [u'Papa']
# [u'Papa']
# [u'Johnny']
# [u'Johnny']
# [u'Blanca']
# [u'Blanca']
# [u'John']
# [u'Batman']
# [u'Justin']
# [u'Justin']
# [u'Alexander']
# [u'Alexander']
# [u'Chuck']
# [u'Chuck']
# []
# []
# []
# []
# []
# [u'Dave']
# [u'Dave']
# []
# []
# [u'John']
# [u'John']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Ron']
# [u'Ron']
# [u'Mike']
# [u'Pete']
# [u'Pete']
# []
# []
# [u'Martha']
# [u'Martha']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Carey']
# [u'Carey']
# [u'William']
# [u'William']
# [u'Sam']
# [u'Sam']
# []
# []
# [u'ROGER']
# []
# []
# [u'Frank']
# [u'Frank']
# []
# []
# []
# []
# []
# [u'DODIE']
# [u'Ledisi']
# [u'Ledisi']
# []
# []
# [u'Erykah']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Chris']
# [u'Diana']
# [u'Rick']
# [u'Rich']
# [u'Jadakiss']
# []
# [u'Lil']
# []
# []
# [u'Ansolo']
# [u'Ansolo']
# []
# []
# [u'James']
# [u'James']
# []
# []
# []
# []
# [u'Laidback', u'Luke']
# [u'Laidback', u'Luke']
# [u'Martin']
# [u'Martin']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Caroline']
# [u'Caroline']
# []
# []
# []
# []
# [u'Robbie']
# [u'Robbie']
# []
# []
# [u'PETE']
# [u'PETE']
# [u'ELLA']
# [u'ELLA']
# [u'ROGER']
# [u'BARBARA']
# [u'BARBARA']
# [u'BILLY']
# [u'BILLY']
# []
# []
# [u'JOHN']
# [u'JOHN']
# [u'DODIE']
# [u'ISAAC']
# [u'ISAAC']
# [u'R.']
# [u'R.']
# [u'DELBERT']
# [u'DELBERT']
# []
# []
# [u'LYNN']
# [u'Vivian']
# [u'LYNN']
# [u'EDWIN']
# [u'EDWIN']
# []
# []
# []
# [u'LEO']
# [u'LEO']
# [u'LLOYD']
# [u'LLOYD']
# [u'P.J.']
# [u'P.J.']
# [u'HUEY']
# [u'HUEY']
# []
# []
# []
# []
# []
# []
# []
# [u'Judas']
# [u'Judas']
# [u'Jonathan']
# [u'Jonathan']
# []
# []
# [u'Vivian']
# []
# []
# []
# [u'Hicks']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Hicks']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'John']
# []
# []
# []
# []
# []
# [u'JASON']
# [u'JASON']
# []
# []
# []
# []
# []
# []
# []
# [u'ELLIE']
# []
# []
# []
# []
# []
# [u'JUSTIN']
# [u'JUSTIN']
# []
# []
# []
# []
# []
# [u'JASON']
# [u'JASON']
# []
# []
# []
# []
# []
# []
# [u'KENDRICK']
# [u'KENDRICK']
# []
# []
# []
# []
# []
# [u'ELLIE']
# []
# []
# []
# [u'JENNIFER']
# [u'JENNIFER']
# []
# []
# []
# []
# []
# [u'John']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Sia']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Jessica']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Stacey']
# [u'Reggie']
# []
# []
# []
# [u'Nicki']
# []
# []
# []
# []
# [u'Letra']
# [u'Letra']
# [u'Gorilla']
# []
# []
# []
# []
# [u'Letra']
# [u'Letra']
# []
# []
# []
# []
# []
# []
# []
# [u'Letra']
# [u'Letra']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Letra']
# [u'Letra']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Romain']
# [u'Romain']
# [u'Joe']
# [u'Joe']
# []
# [u'Bj']
# [u'Bj']
# []
# []
# [u'Joey']
# [u'Joey']
# [u'Bailey']
# [u'Bailey']
# [u'Gorilla']
# []
# []
# []
# []
# [u'Mary']
# [u'Mary']
# []
# []
# [u'Pentatonix']
# [u'Pentatonix']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Ellen', u'David']
# [u'Ellen', u'David']
# [u'Aziz']
# [u'Aziz']
# [u'Evan']
# [u'Evan']
# []
# []
# [u'Sia']
# []
# []
# []
# []
# []
# [u'Eric']
# []
# [u'Eric']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Lydia']
# [u'Lydia']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Diana']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Elvis', u'Presley']
# [u'Elvis', u'Presley']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Tracy', u'Byrd']
# [u'Tracy', u'Byrd']
# []
# []
# []
# []
# [u'George', u'Strait']
# [u'George', u'Strait']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Carl']
# []
# [u'Carl']
# []
# []
# []
# []
# []
# []
# [u'Kevin']
# [u'Kevin']
# []
# [u'Eddy']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Caitlyn']
# [u'Caitlyn']
# [u'Kristen']
# [u'Kristen']
# [u'Tom']
# [u'Tom']
# []
# []
# []
# []
# [u'Diane']
# [u'Diane']
# [u'Britney']
# [u'Marlon']
# [u'Marlon']
# []
# []
# [u'Cheryl']
# [u'Cheryl']
# [u'Shawn']
# [u'Shawn']
# [u'Britney']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Danny']
# [u'Danny']
# [u'Sidney']
# [u'Sidney']
# [u'Laidback', u'Luke']
# [u'Laidback', u'Luke']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Jack']
# []
# [u'Jack']
# [u'Martin']
# [u'Martin']
# []
# []
# [u'Martin']
# [u'Martin']
# []
# []
# []
# []
# []
# [u'Eddy']
# [u'Della']
# [u'Della']
# [u'Eric']
# [u'Eric']
# []
# [u'George']
# [u'George']
# [u'Elle']
# []
# [u'Elle']
# []
# []
# []
# []
# []
# [u'Bob']
# [u'Bob']
# [u'K.T.']
# []
# [u'K.T.']
# []
# []
# [u'Akon']
# [u'Akon']
# [u'Svenska']
# [u'Svenska']
# [u'Marty']
# [u'Marty']
# []
# [u'Steve', u'Green']
# [u'Steve', u'Green']
# []
# []
# []
# []
# []
# []
# []
# [u'Michael', u'Myers']
# [u'Michael', u'Myers']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'James', u"Bond's"]
# [u'James', u"Bond's"]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Dee', u'Dee', u'Bridgewater']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Dj', u'BlAcKoUt', u'Kelowna']
# [u'Dj', u'BlAcKoUt', u'Kelowna']
# [u'Janet', u'Jackson']
# []
# []
# []
# []
# []
# []
# [u'Annie', u'Mac', u'Cardiff']
# [u'Alice']
# [u'Tony', u'Bennett']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Danielle', u'Bradbery', u'Brett', u'Eldredge']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Reba', u'McEntire']
# [u'Reba', u'McEntire']
# []
# []
# [u'Brantley', u'Gilbert', u'Michael', u'Ray']
# [u'Brantley', u'Gilbert', u'Michael', u'Ray']
# []
# []
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# []
# []
# []
# [u'Michael']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Jefferson', u'Hamer']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# []
# []
# []
# []
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# [u'Billy', u'Flynn']
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# [u'McDowell']
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# [u'Jane', u'Lee', u'Hooker']
# []
# [u'Justin', u'Bieber', u'Fargo']
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# [u'Barbara']
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# [u'Mayer', u'Hawthorne', u'Daryl', u'Hall']
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# [u'Pentatonix', u'Echosmith', u'Rachel', u'Platten']
# []
# []
# [u'Ron', u'Pope']
# [u'Ron', u'Pope', u'Truett', u'Jonathan']
# []
# []
# []
# []
# [u'Milo', u'Philadelphia', u'Kung']
# []
# [u'Martha', u'Tilston']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Bobby', u'Bones']
# [u'Bobby', u'Bones']
# []
# []
# []
# []
# [u'Ronnie', u'McDowell']
# [u'Ronnie', u'McDowell']
# [u'Aaron', u'Lee', u'Tasjan']
# [u'Lee', u'Foss']
# []
# []
# []
# []
# []
# [u'Frank', u'Sinatra', u'Jr.', u'Davenport']
# [u'Frank', u'Sinatra', u'Jr.', u'Davenport']
# [u'Neil', u'Sedaka']
# []
# []
# []
# []
# []
# []
# [u'Ledisi', u'Washington']
# []
# []
# []
# []
# []
# []
# []
# [u'Neil', u'Sedaka']
# []
# []
# []
# []
# [u'Paul', u'Anka']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Landlady', u'Nels', u'Cline', u'Eli']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Warren', u'Haynes']
# [u'Roger', u'Cicero', u'Neuruppin']
# []
# [u'Tommy', u'Emmanuel', u'Santa', u'Barbara']
# [u'Paul', u'Jones']
# [u'Billy', u'Walton', u'Band']
# []
# []
# []
# [u'John', u'Fogerty']
# []
# []
# [u'Martin', u'Hayes']
# []
# []
# [u'Delbert', u'McClinton']
# [u'Delbert', u'McClinton']
# []
# [u'Richard', u'Nader', u'Mitch', u'Ryder']
# []
# []
# [u'Paul', u'Anka', u'Lynn']
# []
# [u'Jake', u'Starr']
# []
# []
# []
# []
# [u'Ron', u'Sayer']
# []
# []
# [u'Harry', u'Dunfermline']
# [u'Kevin']
# [u'Jimmy', u'Buffett', u'Coral', u'Reefer', u'Band']
# [u'Jimmy', u'Buffett', u'Coral', u'Reefer', u'Band']
# []
# []
# []
# []
# []
# []
# []
# [u'Buffy']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Dan', u'Hicks']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Dan', u'Hicks']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Jason', u'Aldean', u'Thomas', u'Rhett']
# [u'Jason', u'Aldean', u'Thomas', u'Rhett']
# []
# []
# []
# []
# [u'Fokin', u'Biches']
# []
# [u'Justin', u'Bieber']
# [u'Ellie', u'Goulding']
# []
# []
# []
# []
# []
# [u'Justin', u'Bieber', u'Fargo']
# [u'Justin', u'Bieber', u'Fargo']
# []
# []
# []
# []
# []
# []
# [u'Jason', u'Payne']
# []
# [u'Aiko']
# [u'Jason', u'Derlo', u'Boondall']
# [u'Jason', u'Derlo', u'Boondall']
# []
# []
# []
# [u'Kendrick', u'Scott', u'Oracle']
# []
# []
# [u'Travis']
# []
# []
# [u'Ellie', u'Goulding']
# []
# []
# []
# []
# [u'Ramiro', u'Lopez']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Kenny', u'Rogers', u'Linda']
# [u'Kevin']
# [u'Kenny', u'Rogers', u'Linda']
# [u'Van', u'Morrison']
# [u'Van', u'Morrison']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Black', u'Sabbath']
# [u'Black', u'Sabbath']
# [u'Patti', u'Smith']
# [u'Jackie']
# [u'Judy']
# []
# []
# [u'Sanctus']
# [u'Sanctus']
# [u'Jackie']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Liao']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Elvis', u'Depressedly']
# [u'Elvis', u'Depressedly']
# [u'Alison', u'Wonderland', u'Manchester']
# []
# []
# [u'Isla', u'Krupoviesa']
# [u'Bestia', u'Beb', u'Riel']
# [u'Manolo', u'Garca']
# []
# []
# []
# [u'Randy', u'Niles']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Justin', u'Bieber', u'Fargo']
# [u'Justin', u'Bieber', u'Fargo']
# [u'Simpson']
# [u'Abraham', u'James', u'Akron']
# []
# []
# [u'Marc', u'Anthony', u'Manhattan']
# []
# []
# []
# []
# []
# []
# []
# [u'Turin', u'Samo']
# []
# []
# []
# []
# []
# [u'Romain', u'Collin']
# [u'Joe', u'Goddard']
# [u'Joe', u'Goddard']
# []
# []
# [u'Erin', u'Harpe']
# []
# []
# []
# [u'Joey', u'DeFrancesco']
# []
# [u'Marco', u'Bailey']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Ellen', u'Season']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Ellen', u'Season']
# []
# [u'Ellen', u'Season']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Bobby', u'Bare', u'Jr.']
# []
# [u'Billy', u'Joel', u'Tampa']
# []
# [u'Ralph', u'Moore']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Michael', u'Henderson']
# []
# [u'Alan', u'Parsons']
# []
# [u'Randy', u'Niles']
# []
# []
# []
# []
# []
# [u'Brandon', u'Gibbs']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Paul', u'Anka']
# []
# []
# [u'John', u'Scofield']
# [u'Kyle', u'Hollingsworth']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Joe', u'Ely']
# [u'Joe', u'Ely']
# []
# []
# []
# []
# [u'Rascal', u'Flatts']
# [u'Jon', u'Wolfe']
# [u'Jon', u'Wolfe']
# []
# [u'Collin', u'Raye']
# [u'Collin', u'Raye']
# []
# []
# []
# [u'Elvis', u'Depressedly']
# []
# [u'Luke', u'Jackson']
# []
# [u'Owen', u'Pallett', u'Waterloo']
# []
# [u'Roger', u'Cicero', u'Neuruppin']
# [u'Charlie', u'Daniels']
# [u'Charlie', u'Daniels']
# []
# [u'Tim', u'Olstad']
# []
# [u'Justin', u'Moore']
# []
# []
# []
# [u'Norman', u'Watt-Roy']
# [u'Tracy', u'Byrd', u'Monroe']
# [u'Tracy', u'Byrd', u'Monroe']
# [u'Vince', u'Gill']
# [u'Vince', u'Gill']
# [u'Garth', u'Brooks']
# [u'Garth', u'Brooks']
# [u'Chris', u'Brade', u'Band']
# [u'Chris', u'Brade', u'Band']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Purgatory', u'Philadelphia', u'Kung']
# []
# [u'Purgatory', u'Philadelphia', u'Kung']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Travis']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Ro']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Boddie']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Reese', u'Van']
# [u'Caroline', u'Reese']
# []
# []
# []
# []
# []
# []
# [u'Alice']
# [u'Vance', u'Joy', u'Elle', u'King']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Rene', u'Marie']
# [u'Clayton']
# []
# []
# [u'Den', u'Svenska', u'Bjrnstammen']
# [u'Den', u'Svenska', u'Bjrnstammen']
# [u'Marty', u'Friedman']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Buffy']
# []

# %%
#start_desc_ner = extract_named_entities(webpage_data.start_description, 10000)
end_desc_ner = extract_named_entities(webpage_data.end_decription, 10000)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Danielle']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'McDowell']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Bobby']
# [u'Bobby']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Jimmy']
# [u'Jimmy']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Justin']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Bestia']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Kyle']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
# back to string
def list_to_string(input_list):
    not_unicode = []
    for item in input_list:
        not_unicode.append(str(item))
    string = str(not_unicode)
    string = string.replace(',','')
    string = string.replace('\'', '')
    string = string.replace('[', '')
    string = string.replace(']', '')
    return string

def ner_to_string_list(ner_list):
    new_list = []
    for item in ner_list:
        new_list.append(list_to_string(item))
    return new_list

# %%
# convert them all into lists of strings so that my tfidf function works with them 
end_body_ner_str = ner_to_string_list(end_body_ner)
start_body_ner_str = ner_to_string_list(start_body_ner)
end_title_ner_str = ner_to_string_list(end_title_ner)
start_title_ner_str = ner_to_string_list(start_title_ner)
end_desc_ner_str = ner_to_string_list(end_desc_ner)
start_desc_ner_str = ner_to_string_list(start_desc_ner)

# calculate tfidf and cosine similarity here 
body_ner_cosine, body_ner_tfidf = get_tfidf_cosine_measure(start_body_ner_str, end_body_ner_str)
title_ner_cosine, title_ner_tfidf = get_tfidf_cosine_measure(start_title_ner_str, end_title_ner_str)
desc_ner_cosine, desc_ner_tfidf = get_tfidf_cosine_measure(start_desc_ner_str, end_desc_ner_str)

# %%
#### an alternative is to just take the intersection and see if that's going to help,
#alhtough to be honest it should work out roughly the same as the tfidf really

# function to find the size of the intersection of the ner's for start and end url pieces 

def ner_intersection(ner_list1, ner_list2):
    intersections = []
    indexer = range(0,len(end_body_ner))
    
    for index in indexer: 
        start_ner_list = set(ner_list1[index])
        end_ner_list = set(ner_list2[index])
        intersection = start_ner_list.intersection(end_ner_list)
        intersections.append(len(intersection))
    
    return intersections
# a
body_ner_intersections = ner_intersection(start_body_ner, end_body_ner)
title_ner_intersections = ner_intersection(start_title_ner, end_title_ner)
desc_ner_intersections = ner_intersection(start_desc_ner, end_desc_ner)

# %% [markdown]
# # aggregate all of this into a single df

# %%
# create df with extracted signals
signal_df = pd.DataFrame()
signal_df['_unit_id'] = webpage_data['_unit_it']

#tfidf cosine similarity
signal_df['title_sim'] = title_cosine 
signal_df['body_sim'] = body_cosine
signal_df['meta_sim'] = meta_cosine

#ngrams
signal_df['one_grams'] = one_grams
signal_df['two_grams'] = two_grams
signal_df['three_grams'] = three_grams

#meta 
signal_df['meta_one_gram'] = description_one_grams
signal_df['meta_two_gram'] = description_two_grams
signal_df['meta_three_gram'] = description_three_grams

# start and end urls
signal_df['starturl'] = webpage_data['starturl']
signal_df['endurl'] = webpage_data['endurl']

# domains
signal_df['start_domain'] = webpage_data['start_domain']
signal_df['end_domain'] = webpage_data['end_domain']

# quant_lcf
signal_df['body_lcf_score'] = body_lcf_score
signal_df['title_lcf_score'] = title_lcf_score
signal_df['desc_lcf_score'] = desc_lcf_score

# # ner cosine values 
signal_df['body_ner_cosine'] = body_ner_cosine
signal_df['title_ner_cosine'] = title_ner_cosine
signal_df['desc_ner_cosine'] = desc_ner_cosine

# # ner intersction values 
signal_df['body_ner_intersection'] = body_ner_intersections
signal_df['title_ner_intersection'] = title_ner_intersections
signal_df['desc_ner_intersectipon'] = desc_ner_intersections

# %%
# filter by the unit_id pairs for which I have a a decent aggregated score 
scores_df = pd.read_csv('scores_exp2.csv')
majority_set = set(scores_df._unit_id)
signal_df['has_majority'] = signal_df['_unit_id'].apply(lambda x: x in majority_set)
signal_df = signal_df[signal_df['has_majority'] == 1]

#add in the scores for histograms to evaluate signals 
id_score_dict = dict(zip(scores_df._unit_id, scores_df.score))
score_list = []
for unit_id in signal_df._unit_id:
    score_list.append(id_score_dict[unit_id])
signal_df['score'] = score_list

# drop the has majority column
del signal_df['has_majority']

# %% [markdown]
# # visualize all of features
# basic first pass assessment, ensure that green is roughly to the right of blue

# %%
print signal_df.groupby('score').mean()
# Out:
#            _unit_id  title_sim  body_sim  meta_sim  one_grams  two_grams  \
# score
# 1      8.662378e+08   0.120559  0.049044  0.074021   0.331421   0.102462
# 3      8.662377e+08   0.348333  0.151382  0.125263   0.353254   0.139279
#
#        three_grams  meta_one_gram  meta_two_gram  meta_three_gram  \
# score
# 1         0.044061       0.362348       0.137118         0.048161
# 3         0.083642       0.327832       0.122676         0.047543
#
#        body_lcf_score  title_lcf_score  desc_lcf_score  body_ner_cosine  \
# score
# 1            0.154671         0.163859        0.125574         0.009597
# 3            0.391129         0.552419        0.326613         0.106568
#
#        title_ner_cosine  desc_ner_cosine  body_ner_intersection  \
# score
# 1              0.017152                0               0.033691
# 3              0.047280                0               0.411290
#
#        title_ner_intersection  desc_ner_intersectipon
# score
# 1                    0.019908                       0
# 3                    0.048387                       0

# %%
### now that we can make some decent graphs to evalute the quality of my features!!! 
signal_df['majority'] = signal_df['score']
signal_df.groupby('majority')['title_sim'].hist(bins= 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: title_sim, dtype: object

# %%
signal_df.groupby('majority')['body_sim'].hist(bins= 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: body_sim, dtype: object

# %%
signal_df.groupby('majority')['meta_sim'].hist(bins= 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: meta_sim, dtype: object

# %%
signal_df.groupby('majority')['one_grams'].hist(bins = 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: one_grams, dtype: object

# %%
signal_df.groupby('majority')['two_grams'].hist(bins = 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: two_grams, dtype: object

# %%
signal_df.groupby('majority')['three_grams'].hist(bins = 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: three_grams, dtype: object

# %%
signal_df.groupby('majority')['meta_one_gram'].hist(bins = 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: meta_one_gram, dtype: object

# %%
signal_df.groupby('majority')['meta_two_gram'].hist(bins = 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: meta_two_gram, dtype: object

# %%
signal_df.groupby('majority')['meta_three_gram'].hist(bins = 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: meta_three_gram, dtype: object

# %%
signal_df.groupby('majority')['body_lcf_score'].hist(bins = 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: body_lcf_score, dtype: object

# %%
signal_df.groupby('majority')['title_lcf_score'].hist(bins = 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: title_lcf_score, dtype: object

# %%
signal_df.groupby('majority')['desc_lcf_score'].hist(bins = 30)
# Out:
# majority
# 1    Axes(0.125,0.125;0.775x0.775)
# 3    Axes(0.125,0.125;0.775x0.775)
# Name: desc_lcf_score, dtype: object

# %%
signal_df.groupby('majority')['body_ner_cosine'].hist(bins = 10)
signal_df.groupby('majority')['body_ner_cosine'].mean()
# Out:
# majority
# 1    0.009597
# 3    0.106568
# Name: body_ner_cosine, dtype: float64

# %%
signal_df.groupby('majority')['title_ner_cosine'].hist(bins = 10)
signal_df.groupby('majority')['title_ner_cosine'].mean()
# Out:
# majority
# 1    0.017152
# 3    0.047280
# Name: title_ner_cosine, dtype: float64

# %%
signal_df.groupby('majority')['desc_ner_cosine'].hist(bins = 5)
signal_df.groupby('majority')['desc_ner_cosine'].mean()
# Out:
# majority
# 1    0
# 3    0
# Name: desc_ner_cosine, dtype: float64

# %%
signal_df.groupby('majority')['title_ner_intersection'].hist(bins = 10)
signal_df.groupby('majority')['title_ner_intersection'].mean()
# Out:
# majority
# 1    0.019908
# 3    0.048387
# Name: title_ner_intersection, dtype: float64

# %%
signal_df.groupby('majority')['body_ner_intersection'].hist(bins = 10)
signal_df.groupby('majority')['body_ner_intersection'].mean()
# Out:
# majority
# 1    0.033691
# 3    0.411290
# Name: body_ner_intersection, dtype: float64

# %%
signal_df.groupby('majority')['desc_ner_intersectipon'].hist(bins = 10)
signal_df.groupby('majority')['desc_ner_intersectipon'].mean()
# Out:
# majority
# 1    0
# 3    0
# Name: desc_ner_intersectipon, dtype: int64

# %% [markdown]
# ## output to database

# %%
# output to the unit pair signal db
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2

dbname = 'urx'
username = 'noahburbank'

engine = create_engine('postgres://%s@localhost/%s'%(username,dbname))

# %%
signal_df.to_sql('signals_exp2', engine, if_exists = 'replace')
