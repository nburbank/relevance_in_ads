# %%
import pandas as pd

# %%
# import data
raw_df = pd.read_csv('f835051.csv')

# %%
# Out:
# 6426    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 6427    3
# Name: please_make_your_relevancy_judgment, dtype: int64
# 6428    2
# Name: please_make_your_relevancy_judgment, dtype: int64
# 6429    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 6430    3
# Name: please_make_your_relevancy_judgment, dtype: int64
# 6431    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 6432    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 6433    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 6434    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 6435    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 10872    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 10873    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 10874    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 10875    1
# Name: please_make_your_relevancy_judgment, dtype: int64
# 10876    1
# ...

# %%
# Out:
# [[...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
#  [...],
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2264251b8373> in <module>()
# ----> 1 score_df['scores'].hist()
#
# /Users/noahburbank/anaconda/envs/py2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2899         values = self.dropna().values
#    2900
# -> 2901         ax.hist(values, bins=bins, **kwds)
#    2902         ax.grid(grid)
#    2903         axes = np.array([ax])
#
# /Users/noahburbank/anaconda/envs/py2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5676             # this will automatically overwrite bins,
#    5677             # so that each histogram uses the same bins
# ...

# %%
len(raw_df.groupby('_unit_id')['please_make_your_relevancy_judgment'].mean())
# Out:
# 1034
